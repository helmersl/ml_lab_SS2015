# %%
import numpy as np
import pylab as pl
import random
import ps1_implementation as imp
imp = reload(imp)
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib
# WARNING: pylab import has clobbered these variables: ['random', 'e']
# `%matplotlib` prevents importing * from pylab and numpy

# %%
usps_data = np.load('/Users/helmel01/Documents/uni_ss2015/ml_lab_SS2015/hw1/usps.npz')
usps_data.files
usps_patterns = usps_data['data_patterns']
Z,U,D = imp.pca(usps_patterns,256)
print U[:,0:6].shape
max_val = np.max(U)
print max_val
fig, axes = pl.subplots(1,3,figsize=(15,3))
axes[0].bar(np.arange(1,257),D)
axes[1].bar(np.arange(1,26),D[:25])
axes[2].imshow(U[:,0:6], extent=[0,6,0,256])
plt.tight_layout()
# Out:
# (256, 6)
# 0.289876162889

# %%
pl.imshow(U[:,0:200])

# %%
def usps():
    ''' performs the usps analysis for assignment 4'''
    with np.load('/Users/helmel01/Documents/uni_ss2015/ml_lab_SS2015/hw1/usps.npz') as usps_data:
        print usps_data.shape


usps()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-19-2f8117b26ff9> in <module>()
# ----> 1 usps()
#
# <ipython-input-18-5fd2b3297580> in usps()
#       2     ''' performs the usps analysis for assignment 4'''
#       3     with np.load('/Users/helmel01/Documents/uni_ss2015/ml_lab_SS2015/hw1/usps.npz') as usps_data:
# ----> 4         print usps_data.shape
#
# AttributeError: 'NpzFile' object has no attribute 'shape'
