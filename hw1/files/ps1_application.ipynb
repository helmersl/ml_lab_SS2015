# %%
import numpy as np
import pylab as pl
import random
import ps1_implementation as imp
from sklearn.metrics import roc_auc_score
imp = reload(imp)
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib
# WARNING: pylab import has clobbered these variables: ['random']
# `%matplotlib` prevents importing * from pylab and numpy

# %%
usps_data = np.load('/Users/helmel01/Documents/uni_ss2015/ml_lab_SS2015/hw1/usps.npz')
usps_data.files
usps_patterns = usps_data['data_patterns']
Z_usps,U_usps,D_usps = imp.pca(usps_patterns,256)
fig2, axes2 = pl.subplots(1,5,figsize=(15,3))
for i in range(5):
    comp = np.reshape(U_usps[:,i], (16,16))
    axes2[i].imshow(comp)
pl.tight_layout()

# %%
fig, axes = pl.subplots(1,2,figsize=(15,3))
axes[0].bar(np.arange(1,257),D_usps)
axes[0].set_ylim(0,23)
axes[0].set_title("Principal Values")
axes[1].bar(np.arange(1,26),D_usps[:25])
axes[1].set_title("25 largest principal Values")
axes[1].set_ylim(0,23)
pl.tight_layout()

# %%
usps_low_noise = usps_patterns + 0.2*np.random.randn(usps_patterns.shape[0], usps_patterns.shape[1])

Z_low_noise,U_low_noise,D_low_noise = imp.pca(usps_low_noise,256)
fig, axes = pl.subplots(1,2,figsize=(15,3))
axes[0].bar(np.arange(1,257),D_low_noise)
axes[0].set_ylim(0,23)
axes[0].set_title("Principal Values")
axes[1].bar(np.arange(1,26),D_low_noise[:25])
axes[1].set_title("25 largest principal Values")
axes[1].set_ylim(0,23)
pl.tight_layout()

# %%
usps_high_noise = usps_patterns + 1.5*np.random.randn(usps_patterns.shape[0], usps_patterns.shape[1])

Z_high_noise,U_high_noise,D_high_noise = imp.pca(usps_high_noise,256)
fig, axes = pl.subplots(1,2,figsize=(15,3))
axes[0].bar(np.arange(1,257),D_high_noise)
axes[0].set_ylim(0,23)
axes[0].set_title("Principal Values")
axes[1].bar(np.arange(1,26),D_high_noise[:25])
axes[1].set_title("25 largest principal Values")
axes[1].set_ylim(0,23)
pl.tight_layout()

# %%
noisy_images_inds = np.random.randint(0,256,5)
print noisy_images_inds
noise = 8*np.random.randn(256,5)
usps_outliers = usps_patterns.copy()
usps_outliers[:,noisy_images_inds] = usps_outliers[:,noisy_images_inds] + noise
Z_outliers,U_outliers,D_outliers = imp.pca(usps_outliers,256)
fig, axes = pl.subplots(1,2,figsize=(15,3))
axes[0].bar(np.arange(1,257),D_outliers)
axes[0].set_ylim(0,23)
axes[0].set_title("Principal Values")
axes[1].bar(np.arange(1,26),D_outliers[:25])
axes[1].set_title("25 largest principal Values")
axes[1].set_ylim(0,23)
pl.tight_layout()
# Out:
# [164 195  42  58 174]

# %%
# 3 b)
#Reconstruction
Z_usps,U_usps,D_usps = imp.pca(usps_patterns,15)
print Z_usps.shape, U_usps[:,0:10].shape

reconstr_usps = usps_patterns.mean(axis=1)[:,np.newaxis] + U_usps[:,0:15].dot(Z_usps)
fig2, axes2 = pl.subplots(1,5,figsize=(15,3))
for i in range(5):
    comp = np.reshape(reconstr_usps[:,i], (16,16))
    axes2[i].imshow(comp)
pl.tight_layout()
# Out:
# (15, 2007) (256, 10)

# %%
#Low noise data
Z_low_noise,U_low_noise,D_low_noise = imp.pca(usps_low_noise,15)
reconstr_low_noise = usps_patterns.mean(axis=1)[:,np.newaxis] + U_low_noise[:,0:15].dot(Z_low_noise)
fig2, axes2 = pl.subplots(1,5,figsize=(15,3))
for i in range(5):
    comp = np.reshape(reconstr_low_noise[:,i], (16,16))
    axes2[i].imshow(comp)
pl.tight_layout()

# %%
#High noise data
Z_high_noise,U_high_noise,D_high_noise = imp.pca(usps_high_noise,15)
reconstr_high_noise = usps_patterns.mean(axis=1)[:,np.newaxis] + U_high_noise[:,0:15].dot(Z_high_noise)
fig2, axes2 = pl.subplots(1,5,figsize=(15,3))
for i in range(5):
    comp = np.reshape(reconstr_high_noise[:,i], (16,16))
    axes2[i].imshow(comp)
pl.tight_layout()

# %%
#Outlier data
Z_outliers,U_outliers,D_outliers = imp.pca(usps_outliers,15)
reconstr_outliers = usps_patterns.mean(axis=1)[:,np.newaxis] + U_outliers[:,0:15].dot(Z_outliers)
fig2, axes2 = pl.subplots(1,5,figsize=(15,3))
for i in range(5):
    comp = np.reshape(reconstr_outliers[:,i], (16,16))
    axes2[i].imshow(comp)
pl.tight_layout()

# %%
fig, axes = pl.subplots(10,3, figsize = (8,15))

axes[0,0].imshow(np.reshape(usps_patterns[:,42], (16,16)))
axes[0,1].imshow(np.reshape(usps_outliers[:,42], (16,16)))
axes[0,2].imshow(np.reshape(reconstr_outliers[:,42], (16,16)))

axes[1,0].imshow(np.reshape(usps_patterns[:,2], (16,16)))
axes[1,1].imshow(np.reshape(usps_low_noise[:,2], (16,16)))
axes[1,2].imshow(np.reshape(reconstr_low_noise[:,2], (16,16)))

axes[2,0].imshow(np.reshape(usps_patterns[:,0], (16,16)))
axes[2,1].imshow(np.reshape(usps_high_noise[:,0], (16,16)))
axes[2,2].imshow(np.reshape(reconstr_high_noise[:,0], (16,16)))

axes[3,0].imshow(np.reshape(usps_patterns[:,174], (16,16)))
axes[3,1].imshow(np.reshape(usps_outliers[:,174], (16,16)))
axes[3,2].imshow(np.reshape(reconstr_outliers[:,174], (16,16)))

axes[4,0].imshow(np.reshape(usps_patterns[:,174], (16,16)))
axes[4,1].imshow(np.reshape(usps_low_noise[:,174], (16,16)))
axes[4,2].imshow(np.reshape(reconstr_low_noise[:,174], (16,16)))

axes[5,0].imshow(np.reshape(usps_patterns[:,174], (16,16)))
axes[5,1].imshow(np.reshape(usps_high_noise[:,174], (16,16)))
axes[5,2].imshow(np.reshape(reconstr_high_noise[:,174], (16,16)))

axes[6,0].imshow(np.reshape(usps_patterns[:,164], (16,16)))
axes[6,1].imshow(np.reshape(usps_outliers[:,164], (16,16)))
axes[6,2].imshow(np.reshape(reconstr_outliers[:,164], (16,16)))

axes[7,0].imshow(np.reshape(usps_patterns[:,164], (16,16)))
axes[7,1].imshow(np.reshape(usps_low_noise[:,164], (16,16)))
axes[7,2].imshow(np.reshape(reconstr_low_noise[:,164], (16,16)))

axes[8,0].imshow(np.reshape(usps_patterns[:,164], (16,16)))
axes[8,1].imshow(np.reshape(usps_high_noise[:,164], (16,16)))
axes[8,2].imshow(np.reshape(reconstr_high_noise[:,164], (16,16)))

axes[9,0].imshow(np.reshape(usps_patterns[:,200], (16,16)))
axes[9,1].imshow(np.reshape(usps_low_noise[:,200], (16,16)))
axes[9,2].imshow(np.reshape(reconstr_low_noise[:,200], (16,16)))

usps_data.close()

# %%
def usps():
    ''' performs the usps analysis for assignment 4'''

# %%
#Assignment 5
banana = np.load("/Users/helmel01/Documents/uni_ss2015/ml_lab_SS2015/hw1/banana_data.npz")

# %%
labels = banana['label']
positive_class_mask = labels == 1
positive_class = np.where(positive_class_mask == True)[1]
negative_class = np.where(positive_class_mask == False)[1]
inliers = banana['data'][:,positive_class]
outliers = banana['data'][:,negative_class]

# %%
def outliers_calc():
    banana = np.load("/Users/helmel01/Documents/uni_ss2015/ml_lab_SS2015/hw1/banana_data.npz")
    labels = banana['label']
    positive_class_mask = labels == 1
    positive_class = np.where(positive_class_mask == True)[1]
    negative_class = np.where(positive_class_mask == False)[1]
    inliers = banana['data'][:,positive_class]
    outliers = banana['data'][:,negative_class]
    
    
    aucs_idx_3 = []
    aucs_idx_10 = []
    aucs_mean_dist = []
    for perc in [0.01,0.05,0.1,0.25]:
        n_outliers = int(perc*inliers.shape[1])
        auc_idx_3 = []
        auc_idx_10 = []
        auc_mean_dist = []
        for i in range(100):
            outlier_inds = np.random.randint(0,outliers.shape[1],n_outliers)
            picked_outliers = outliers[:,outlier_inds]
            contam = np.hstack((inliers, picked_outliers))
            assert(contam.shape[0] == inliers.shape[0])
            assert(contam.shape[1] == inliers.shape[1] + picked_outliers.shape[1])
            gammaidx_3 = imp.gammaidx(contam, 3)
            gammaidx_10 = imp.gammaidx(contam, 10)
            mean_dist = abs(contam - contam.mean(axis=1)[:,np.newaxis])
            
            outlier_idx_3 = np.fliplr(np.argsort(gammaidx_3))
            pred_outlier_idx_3 = outlier_idx_3[:,0:n_outliers]
            pred_idx_3 = np.ones(inliers.shape[1]+n_outliers)
            pred_idx_3[pred_outlier_idx_3] = -1
            
            outlier_idx_10 = np.fliplr(np.argsort(gammaidx_10))
            pred_outlier_idx_10 = outlier_idx_10[:,0:n_outliers]
            pred_idx_10 = np.ones(inliers.shape[1]+n_outliers)
            pred_idx_10[pred_outlier_idx_10] = -1
                
            outlier_mean_dist = np.fliplr(np.argsort(mean_dist))
            pred_outlier_mean_dist = outlier_mean_dist[:,0:n_outliers]
            pred_mean_dist = np.ones(inliers.shape[1]+n_outliers)
            pred_mean_dist[pred_outlier_mean_dist] = -1
                
            true_inds = np.arange(inliers.shape[1], inliers.shape[1]+n_outliers)               
            y_true = np.ones(inliers.shape[1]+n_outliers)
            y_true[true_inds] = -1
            
            fpf
            fnf = 
            roc_auc_3 = roc_auc_score(y_true, pred_idx_3)
            roc_auc_10 = roc_auc_score(y_true, pred_idx_10)
            roc_auc_mean = roc_auc_score(y_true, pred_mean_dist)
            #print roc_auc_3, roc_auc_10, roc_auc_mean
            
            auc_idx_3.append(roc_auc_3)
            auc_idx_10.append(roc_auc_10)
            auc_mean_dist.append(roc_auc_mean)
        aucs_idx_3.append(auc_idx_3)
        aucs_idx_10.append(auc_idx_10)
        aucs_mean_dist.append(auc_mean_dist)
    
    aucs_idx_3 = np.array(aucs_idx_3)
    aucs_idx_10 = np.array(aucs_idx_10)
    aucs_mean_dist = np.array(aucs_mean_dist)
    filename = 'auc_values.npz'
    np.savez(filename, aucs_idx_3 = aucs_idx_3, aucs_idx_10 = aucs_idx_10, aucs_mean_dist = aucs_mean_dist)
# Out:
#   File "<ipython-input-16-ae2840a9f973>", line 49
#     fnf =
#           ^
# SyntaxError: invalid syntax

# %%
from scipy.integrate import simps

def outliers_calc():
    
    banana = np.load("/Users/helmel01/Documents/uni_ss2015/ml_lab_SS2015/hw1/banana_data.npz")
    labels = banana['label']
    positive_class_mask = labels == 1
    positive_class = np.where(positive_class_mask == True)[1]
    negative_class = np.where(positive_class_mask == False)[1]
    inliers = banana['data'][:,positive_class]
    outliers = banana['data'][:,negative_class]
    aucs_idx_3 = []
    aucs_idx_10 = []
    aucs_mean_dist = []
    for perc in [0.01,0.05,0.1,0.25]:
        n_outliers = int(perc*inliers.shape[1])
        auc_idx_3 = []
        auc_idx_10 = []
        auc_mean_dist = []
        for i in range(10):
            outlier_inds = np.random.randint(0,outliers.shape[1],n_outliers)
            picked_outliers = outliers[:,outlier_inds]
            contam = np.hstack((inliers, picked_outliers))
            assert(contam.shape[0] == inliers.shape[0])
            assert(contam.shape[1] == inliers.shape[1] + picked_outliers.shape[1])
            gammaidx_3 = imp.gammaidx(contam, 3)
            gammaidx_10 = imp.gammaidx(contam, 10)
            mean_dist = abs(contam - contam.mean(axis=1)[:,np.newaxis])
            
            #True indices
            true_inds = np.arange(inliers.shape[1], inliers.shape[1]+n_outliers)               
            y_true = np.ones(inliers.shape[1]+n_outliers)
            y_true[true_inds] = -1
            
            #Calculate AUC for each method
            min_3 = np.amin(gammaidx_3)
            max_3 = np.amax(gammaidx_3)
            thresholds_3 = np.linspace(min_3, max_3, 20)
            roy = []
            rox = []
            for thresh in thresholds_3:
                outliers_3 = np.where(gammaidx_3 >= thresh)[1]
                inliers_3 = np.where(gammaidx_3 < thresh)[1]
                fpf = (len(outliers) - len(np.intersect1d(outliers, true_inds))/float(inliers.shape[1]))
                tpf = 1 - (len(np.setdiff1d(true_inds, outliers))/float(n_outliers))
                rox.append(fpf)
                roy.append(tpf)
            roc = np.polyfit(np.array(rox), np.array(roy), 2)
            auc_3 = 1 - simps(rox,roy)
            auc_idx_3.append(auc_3)
                
                
                
            
            
            
            min_10 = np.amin(gammaidx_10)
            max_10 = np.amax(gammaidx_10)
            thresholds_10 = np.linspace(min_10, max_10, 20)
            
            min_m = np.amin(mean_dist)
            max_m = np.amax(mean_dist)
            thresholds_m = np.linspace(min_m, max_m, 20)
            
            outlier_idx_3 = np.fliplr(np.argsort(gammaidx_3))
            pred_outlier_idx_3 = outlier_idx_3[:,0:n_outliers]
            pred_idx_3 = np.ones(inliers.shape[1]+n_outliers)
            pred_idx_3[pred_outlier_idx_3] = -1
            
            outlier_idx_10 = np.fliplr(np.argsort(gammaidx_10))
            pred_outlier_idx_10 = outlier_idx_10[:,0:n_outliers]
            pred_idx_10 = np.ones(inliers.shape[1]+n_outliers)
            pred_idx_10[pred_outlier_idx_10] = -1
                
            outlier_mean_dist = np.fliplr(np.argsort(mean_dist))
            pred_outlier_mean_dist = outlier_mean_dist[:,0:n_outliers]
            pred_mean_dist = np.ones(inliers.shape[1]+n_outliers)
            pred_mean_dist[pred_outlier_mean_dist] = -1
                
            true_inds = np.arange(inliers.shape[1], inliers.shape[1]+n_outliers)               
            y_true = np.ones(inliers.shape[1]+n_outliers)
            y_true[true_inds] = -1
            

            roc_auc_3 = roc_auc_score(y_true, pred_idx_3)
            roc_auc_10 = roc_auc_score(y_true, pred_idx_10)
            roc_auc_mean = roc_auc_score(y_true, pred_mean_dist)
            #print roc_auc_3, roc_auc_10, roc_auc_mean
            
            #auc_idx_3.append(roc_auc_3)
            auc_idx_10.append(roc_auc_10)
            auc_mean_dist.append(roc_auc_mean)
        aucs_idx_3.append(auc_idx_3)
        aucs_idx_10.append(auc_idx_10)
        aucs_mean_dist.append(auc_mean_dist)
    
    aucs_idx_3 = np.array(aucs_idx_3)
    aucs_idx_10 = np.array(aucs_idx_10)
    aucs_mean_dist = np.array(aucs_mean_dist)
    filename = 'auc_values.npz'
    np.savez(filename, aucs_idx_3 = aucs_idx_3, aucs_idx_10 = aucs_idx_10, aucs_mean_dist = aucs_mean_dist)

# %%
outliers_calc()
# Out:
# /Users/helmel01/anaconda/lib/python2.7/site-packages/numpy/lib/polynomial.py:587: RankWarning: Polyfit may be poorly conditioned
#   warnings.warn(msg, RankWarning)
# /Users/helmel01/anaconda/lib/python2.7/site-packages/scipy/integrate/quadrature.py:380: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   x = x.reshape(tuple(shapex))
# /Users/helmel01/anaconda/lib/python2.7/site-packages/numpy/lib/polynomial.py:587: RankWarning: Polyfit may be poorly conditioned
#   warnings.warn(msg, RankWarning)
# /Users/helmel01/anaconda/lib/python2.7/site-packages/scipy/integrate/quadrature.py:380: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   x = x.reshape(tuple(shapex))
# /Users/helmel01/anaconda/lib/python2.7/site-packages/numpy/lib/polynomial.py:587: RankWarning: Polyfit may be poorly conditioned
#   warnings.warn(msg, RankWarning)
# ...

# %%
banana.close()

# %%
def outliers_disp():
    aucs = np.load('auc_values.npz')
    percentages = [1,5,10,25]
    aucs_idx_3 = aucs['aucs_idx_3']
    aucs_idx_10 = aucs['aucs_idx_10']
    aucs_mean_dist = aucs['aucs_mean_dist']
    fig, axes = pl.subplots(1,4,figsize=(20,7))
    for i in range(4):
        axes[i].boxplot([aucs_idx_3[i,:], aucs_idx_10[i,:], aucs_mean_dist[i,:]])
        axes[i].set_title('Distribution of AUC values for %i %% outliers' %percentages[i])
        axes[i].set_ylim(0.4,0.85)
        pl.xticks([1, 2, 3], ['mon', 'tue', 'wed'])
        xtickNames = pl.setp(axes[i], xticklabels=['k=3', 'k=10', 'dist to mean'])
        pl.setp(xtickNames, rotation=30, fontsize=13)
    fig.tight_layout()
    aucs.close()

# %%
outliers_disp()

# %%
#Assignment 6
